# %% [markdown]
# # Assignment 1
#
# This assignment will involve the creation of a spellchecking system and an evaluation of its performance. You may use the code snippets provided in Python for completing this or you may use the programming language or environment of your choice
#
# Please start by downloading the corpus `holbrook.txt` from Blackboard
#
# The file consists of lines of text, with one sentence per line. Errors in the line are marked with a `|` as follows
#
#     My siter|sister go|goes to Tonbury .
#
# In this case the word 'siter' was corrected to 'sister' and the word 'go' was corrected to 'goes'.
#
# In some places in the corpus two words maybe corrected to a single word or one word to a multiple words. This is denoted in the data using underscores e.g.,
#
#     My Mum goes out some_times|sometimes .
#
# For the purpose of this assignment you do not need to separate these words, but instead you may treat them like a single token.
#
# *Note: you may use any functions from NLTK to complete the assignment. It should not be necessary to use other libraries and so please consult with us if your solution involves any other external library. If you use any function from NLTK in Task 6 please include a brief description of this function and how it contributes to your solution.*

# %% [markdown]
# ## Task 1 (10 Marks)
#
# Write a parser that can read all the lines of the file `holbrook.txt` and print out for each line the original (misspelled) text, the corrected text and the indexes of any changes. The indexes refers to the index of the words in the sentence. In the example given, there is only an error in the 10th word and so the list of indexes is [9]. It is not necessary to analyze where the error occurs inside the word.
#
# Then split your data into a test set of 100 lines and a training set.

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.path.isfile("drive/Cplab Notebooks/NLP Assignment 1")
lines = open("holbrook.txt").readlines()
lines
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['1 .\n',
#  'NIGEL THRUSH page 48\n',
#  'I have four in my Family Dad Mum and siter|sister .\n',
#  'My Dad works at Melton .\n',
#  'My siter|sister go|goes to Tonbury .\n',
#  'My Mum goes out some_times|sometimes .\n',
#  'I go to Bridgebrook i go out some_times|sometimes on Tuesday night i go to Youth clob|club .\n',
#  'On thursday nights I go bell_ringing|bellringing on Saturdays I go down to the farm .\n',
#  'on sundays I go to church .\n',
#  'I go to bed at 10 o clock I wakh|watch TV at 5 o clock I live in a house .\n',
#  'The house is in the world .\n',
#  'I live at Boar Parva it is near Melton and Bridgebrook and Smallerden .\n',
#  'The house is white it has stone up the frount|front it is the first from Bridgebrook and the sexeon|second from Smallerden .\n',
# ...

# %%
import nltk
nltk.download('all')

# %%
import nltk
import os
#read line from book
lines = open("holbrook.txt").readlines()
from nltk.tokenize import word_tokenize
#tokenize each word
#split lines
data = [line.replace("\n","").split(" ") for line in lines]
char = "|"
i = 0
out=[]
def correct(data,char):
  for sublist in data:
    #create dictionary
    dict={}
    i=-1
    indexes=[]
    original=[]
    corrected=[]
    for value in sublist:
      i = i+1
      #if character then store split the value 
      #append in corrected and original
      if char in value:
        indexes.append(i)
        split_list = value.split(char)
        original.append(split_list[0])
        corrected.append(split_list[1])
      else:
        original.append(value)
        corrected.append(value)
    
    #print(original)
    #print(corrected)
    dict['original']=original
    dict['corrected']=corrected
    dict['indexes']=indexes
    out.append(dict)
                     
correct(data,char)
print (out[2])






#assert(data[2] == {
# 'original': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and',
# 'corrected': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and',
# 'indexes': [9]
#})
# Out:
# {'corrected': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister', '.'], 'original': ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'siter', '.'], 'indexes': [9]}

# %% [markdown]
# The counts and assertions given in the following sections are based on splitting the training and test set as follows

# %%
print(len(out))
# Out:
# 1223

# %%
test = out[:100]
train=out[100:]
print(out[2]['corrected'])
print(train)
# Out:
# ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister', '.']
# ...

# %% [markdown]
# ## **Task 2** (10 Marks):
# Calculate the frequency (number of occurrences), *ignoring case*, of all words and their unigram probability from the corrected *training* sentences.
#
# *Hint: use `Counter` to implement this so it may be called many times*

# %%
from collections import Counter
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
train=out[100:]
print(train)
counts=[]
word_list=[]
cont=[]
def unigram(token):  
  train=out[100:]
  #if train corrected append words to word_list
  for data in train:
    for word in data['corrected']:
      word_list.append(word)
  #for every word in word_list count the i
  i=[w for w in word_list if w =="me"]
  counts=Counter(i)
  print(counts)
    
#determine the probability
def prob(word_list):
  total=len(word_list)
  i=[w for w in word_list]
  counts=Counter(i)
  #if key then compute its count value and total to determine the probability
  for key in counts:
    cont=float(counts[key])/float(total)
   
    
  return cont
    
unigram(train)   
prob(word_list) #returns probability of last iteration
# Out:
# [{'corrected': ['they', 'can', 'go', 'quite', 'fast'], 'original': ['they', 'can', 'go', 'quite', 'farst'], 'indexes': [4]}, {'corrected': ['this', 'was', 'a', 'Royal', 'Enfield', '_?_'], 'original': ['this', 'was', 'a', 'Royl', 'Enfield', 'Consulatoin'], 'indexes': [3, 5]}, {'corrected': ['there', 'were', 'some', 'Royal', 'Enfield', 'Racing', 'there', 'as', 'well'], 'original': ['there', 'were', 'some', 'Royl', 'Enfield', 'Racing', 'there', 'as', 'well'], 'indexes': [3]}, {'corrected': ['I', 'saw', 'a', 'Royal', 'Enfield', 'come', 'first', 'it', 'was', 'like', 'mine', '.'], 'original': ['I', 'saw', 'a', 'Royl', 'Enfield', 'come', 'first', 'it', 'was', 'like', 'mine', '.'], 'indexes': [3]}, {'corrected': ['there', 'were', 'the', 'new', 'Japanese', 'Honda'], 'original': ['there', 'were', 'the', 'new', 'Japannese', 'Hondor'], 'indexes': [4, 5]}, {'corrected': ['they', 'are', 'very', 'fast', 'and', 'getting', 'quite', 'popular', 'in', 'England'], 'original': ['they', 'are', 'very', 'far
# ...

# %% [markdown]
# ## **Task 3** (15 Marks):
# [Edit distance](https://en.wikipedia.org/wiki/Edit_distance) is a method that calculates how similar two strings are to one another by counting the minimum number of operations required to transform one string into the other. There is a built-in implementation in NLTK that works as follows:

# %% [markdown]
# Write a function that calculates all words with *minimal* edit distance to the misspelled word. You should do this as follows
#
# 1. Collect the set of all unique tokens in `train`
# 2. Find the minimal edit distance, that is the lowest value for the function `edit_distance` between `token` and a word in `train`
# 3. Output all unique words in `train` that have this same (minimal) `edit_distance` value
#
# *Do not implement edit distance, use the built-in NLTK function `edit_distance`*

# %%
import nltk
from nltk.metrics.distance import edit_distance

#store set of unique words of train in unique_words
unique_words = set(word.lower() for word in word_list)
def get_candidates(token):
  #compute distance for two strings
  min_distances = [(edit_distance(token,word),word) for word in unique_words]
  min_value = min(min_distances)[0]
  new_list=[]
  #if count is equal to min value then print its corresponding words
  for (count, word) in min_distances:
    if(count == min_value):
      new_list.append(word)
  return new_list
  
get_candidates("minde")
# Out:
# ['mind', 'mine']

# %% [markdown]
# ## Task 4 (15 Marks):
#
# Write a function that takes a (misspelled) sentence and returns the corrected version of that sentence. The system should scan the sentence for words that are not in the dictionary (set of unique words in the training set) and for each word that is not in the dictionary choose a word in the dictionary that has minimal edit distance and has the highest *unigram probability*.
#
# *Your solution to this should involve `get_candidates`*

# %%
import operator
def correct(sentence):
  word=[]
  word_list=[]  
  corrected_sentence =sentence[:]
  
  for word in sentence:
    #if word not in unique words in train
    if(word not in unique_words):      
      candidates = get_candidates(word)
      #if there are more than one word in candidates then determine its probability
      if(len(candidates)>1):
        probs =[(prob(candidate),candidate) for candidate in candidates]  
        #determine its corresponding word for the given probability
        for p,w in probs:
          if(p==max(probs)):corrected_sentence[corrected_sentence.index(word)] = w
            #print(corrected_sentence)
      else:
        #print the word
        corrected_sentence[corrected_sentence.index(word)]=candidates[0]
    
          
      
  return corrected_sentence
  
  
  
correct(['this','cat','whitr'])
# Out:
# ['this', 'cat', 'white']

# %% [markdown]
# ## **Task 5** (10 Marks):
# Using the test corpus evaluate the *accuracy* of your method, i.e., how many words from your system's output match the corrected sentence (you should count words that are already spelled correctly and not changed by the system).

# %%
print(unique_words)
# Out:
# set(['raining', "jane's", 'yellow', 'four', 'sleep', 'hanging', 'firms', 'captain', 'saved', 'skeleton', 'stinks', 'xtv', 'feeding', 'swam', 'swan', 'sweetest', 'presents', 'bike', 'trousers', 'lord', 'sorry', 'worth', 'sinking', 'rise', 'prowls', "whoever's", 'shoot', 'every', 'jack', 'butlins', 'stabbed', 'monkeys', 'tickets', 'school', 'pinch', 'wednesday', 'sexton', 'triumph', 'clothes', 'enjoy', 'farmhouse', 'bicycle', "tom's", 'midsummer', 'japanese', '10d', 'nail', 'second', 'street', 'sailed', 'phoned', 'shining', 'blue', 'oldest', 'hide', 'thunder', 'above', 'toll', 'new', 'tips', 'ever', 'told', 'whitehall', 'men', 'here', 'met', 'china', 'nanny', 'ploughed', 'path', '100', '101', '106', 'dry', 'leiston', 'kids', 'daughter', 'leaves', 'climbed', 'adopt', '1212', "i'd", 'smoke', "i'm", 'suitable', 'glittering', 'golden', 'prints', 'straw', 'brought', 'ninety', 'meats', 'drowned', 'eastwood', 'would', 'army', 'hospital', 'arms', 'calm', 'h', 'sexy', '25th', 'until', 'calf', '
# ...

# %%
test=out[:100]
word_test=[]
correct_test=[]
def accuracy(test):
  total=0
  count=0
  for line in test:
    for word in line['original']:
      #convert all words to  lower
      word_test.append(word.lower())
  new_sentence = correct(word_test)
  for line in test:
    for word in line['corrected']:
      correct_test.append(word.lower())
      #compare the corrected_test and new corrected test
  for index , word in enumerate(correct_test):
    total += 1
    #if yes then increment count
    if new_sentence[index] == word:
      count += 1
  print(count)
  print(total)
  #determine its accuracy
  accuracy=round(float(count)/total*100)
         
  return accuracy
                          
print(accuracy(test))
# Out:
# 994
# 1129
# 88.0

# %% [markdown]
# ## **Task 6 (35 Marks):**
#
# Consider a modification to your algorithm that would improve the accuracy of the algorithm developed in Task 3 and 4
#
# * You may resources beyond those provided here.
# * You must **not use the test data** in this task.
# * Provide a short text describing what you intend to do and why.
# * Full marks for this section may be obtained without an implementation, but an implementation is preferred.
# * Your implementation should not consist of more than 50 lines of code
#
# Please note this task is marked according to: demonstration of knowledge from the lecutures (10), originality and appropriateness of solution (10), completeness of description (10) and technical correctness (5)

# %% [markdown]
# **STEP1:**
# Parser that can read all the lines of the file holbrook.txt and print out for each line the original (misspelled) text, the corrected text and the indexes of any changes. The indexes refers to the index of the words in the sentence.
#
# **STEP2:**
# **Bigrams probability:**
# Efficient text categorization algorithm that generates bigrams selectively by looking for ones that have an especially good chance of being useful. The algorithm uses the information gain metric, combined with various frequency thresholds. The experimental results suggest that the bigrams can substantially raise the quality of feature sets.
#
# **STEP3: **
# **String Similarity:**
# If the given string is not part of train(corrected) then determine synonyms from the given text. The output of the routine can be more than one string. Hence to determine probability for all the strings. The highest probability of the string is dertermined using naives bayes classifier.
#
# **STEP4:**
# **Naives Bayes Classifier:**
# A classifier based on the Naive Bayes algorithm.  In order to find the
# probability for a label, this algorithm first uses the Bayes rule to
# express P(label|features) in terms of P(label) and P(features|label):
#
# P(label|features) =
#                                  P(label) * P(features|label)/(p(features))
#
# **STEP5:**
# To determine accuracy of the algorithm considering test(original).If test(original) is not part of the train(corrected) words then determine string similarity and probability and append the similar string in new test corrected list.Apply sequence matcher to determine the accuracy.
# **Sequence matcher:**
# In this comparing corrected string and test[‘corrected’] for similarity ratio.If the ratiois more than 95 percentage then increment count and is considered as corrected string.Then compute the accuracy using total and count.

# %%
#Step1:
import nltk
import os
#read line from book
lines = open("holbrook.txt").readlines()
from nltk.tokenize import word_tokenize
#tokenize each word
#split lines
data = [line.replace("\n","").split(" ") for line in lines]
char = "|"
i = 0
out=[]
def correct(data,char):
  for sublist in data:
    #create dictionary
    dict={}
    i=-1
    indexes=[]
    original=[]
    corrected=[]
    for value in sublist:
      i = i+1
      #if character then store split the value 
      #append in corrected and original
      if char in value:
        indexes.append(i)
        split_list = value.split(char)
        original.append(split_list[0])
        corrected.append(split_list[1])
      else:
        original.append(value)
        corrected.append(value)
    
    #print(original)
    #print(corrected)
    dict['original']=original
    dict['corrected']=corrected
    dict['indexes']=indexes
    out.append(dict)
                     
correct(data,char)

#step2
train=out[100:]
test=out[:100]
#bigrams frequency
def bigrams(train):
  for data in train:
    for word in data['corrected']:
      word_list.append(word)
  return list(nltk.bigrams(word_list))
bigram(train)

#step3
#to determine synonyms of the given string
def SimilarString(token):
  newstring_list = []
  unique_words = set(word.lower() for word in word_list)
  for word in token:
    if word not in unique_words:
      for word in string.split():
        if unique_words.synonym(word):
            newstring_list.extend(word_list.synonym(word))
      
  return newstring

SimilarString(token)

#step4
from random import random

def calculate_probability(phrase):
    p = 1.0
    for word in phrase.split():
        word = word.lower()
        p *= prob(word)
        return p * 0.5

def naive_bayes(phrase):
  prob=0
  prob1=[]
  corrected_sentence =phrase[:]
  for prob in phrase:
    prob1.append(calculate_probability(prob))
  for p,w in prob1:
    #to determine the maximum probability
    if(p==max(prob1)):corrected_sentence[corrected_sentence.index(word)] = w
       #print(corrected_sentence)
      else:
        #print the word
        corrected_sentence[corrected_sentence.index(word)]=candidates[0]

naive_bayes(phrase)

#step5
test=out[:100]
word_test=[]
correct_test=[]
def accuracy(test):
  total=0
  count=0
  for line in test:
    for word in line['original']:
      #convert all words to  lower
      word_test.append(word.lower())
  new_sentence = naive_bayes(word_test)
  for line in test:
    for word in line['corrected']:
      correct_test.append(word.lower())
      #compare the corrected_test and new corrected test
    for index , word in enumerate(correct_test):
      total += 1
      #if words match then increment count
      if new_sentence[index] == word:
        count += 1
      else:
        #to determine the ratio of the sequence matcher
        ratio = SequenceMatcher(None, " ".join(word), " ".join(correct_test)).ratio()
        if ratio > 95:
          count=count+1
  accuracy=round(float(count)/total*100)
         
  return accuracy
                          
  print(accuracy(test))

# %% [markdown]
# ## **Task 7 (5 Marks):**
#
# Repeat the evaluation (as in Task 5) of your new algorithm and show that it outperforms the algorithm from Task 3 and 4
